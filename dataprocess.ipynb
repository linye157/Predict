# %%
import pandas as pd

#读取./data/new_Industrial_data.xlsx文件
data = pd.read_excel('./data/new_Industrial_data.xlsx')

# %%
#查看表头
print(data.columns)
#输出前五行数据
print(data.head())
# Out:
# Index(['MAT_WT_T_ODS_L403_TMMHR01', 'MAT_ACT_WT_T_ODS_L403_TMMHR01',
#        'MAT_ACT_THICK_T_ODS_L403_TMMHR01', 'MAT_ACT_WIDTH_T_ODS_L403_TMMHR01',
#        'MAT_TARG_THICK_T_ODS_L403_TMMHR01',
#        'MAT_TARG_WIDTH_T_ODS_L403_TMMHR01', 'SG_STD_T_ODS_L403_TMMHR01',
#        'PSC_T_ODS_L403_TMMHR01', 'APN_T_ODS_L403_TMMHR01',
#        'ORDER_NO_T_ODS_L403_TMMHR01',
#        ...
#        'FCS_TEMP_AVG_T_ODS_L621_TMMCR27', 'IHS_TEMP_AVG_T_ODS_L621_TMMCR27',
#        'SCS_TEMP_AVG_T_ODS_L621_TMMCR27', 'SF_TEMP_AVG_T_ODS_L621_TMMCR27',
#        'RCS_TEMP_AVG_T_ODS_L621_TMMCR27', 'RTF_TEMP_AVG_T_ODS_L621_TMMCR27',
#        'JPF_TEMP_AVG_T_ODS_L621_TMMCR27', 'TS_P1', 'YS_8_P1', 'BREAK_EL_P1'],
#       dtype='object', length=127)
#    MAT_WT_T_ODS_L403_TMMHR01  MAT_ACT_WT_T_ODS_L403_TMMHR01  \
# 0                     28.570                         28.570
# 1                     28.460                         28.460
# 2                     28.830                         28.830
# 3                     29.380                         29.380
# 4                     29.408                         29.408
#
#    MAT_ACT_THICK_T_ODS_L403_TMMHR01  MAT_ACT_WIDTH_T_ODS_L403_TMMHR01  \
# 0                             3.500                            1740.3
# 1                             4.800                            1284.7
# 2                             3.500                            1651.2
# 3                             3.500                            1600.8
# 4                             3.503                            1774.0
#
#    MAT_TARG_THICK_T_ODS_L403_TMMHR01  MAT_TARG_WIDTH_T_ODS_L403_TMMHR01  \
# 0                                3.5                             1722.0
# 1                                4.8                             1272.0
# 2                                3.5                             1638.0
# 3                                3.5                             1585.0
# 4                                3.5                             1755.0
#
#   SG_STD_T_ODS_L403_TMMHR01 PSC_T_ODS_L403_TMMHR01 APN_T_ODS_L403_TMMHR01  \
# 0             BTA BTD010-24       GAd0101EX8014020                 GAC020
# 1              Q/BB385-2022       GAq38512AM000000                 GAB000
# 2             BTA BTD010-24       GAd0101EX9017010                 GAG020
# 3            BTA BTD010-23e       GAd0101EX9010020                 GAG000
# 4             BTA BTD010-24       GAd0101EX9011010                 GAB000
#
#   ORDER_NO_T_ODS_L403_TMMHR01  ... FCS_TEMP_AVG_T_ODS_L621_TMMCR27  \
# 0                 G2470253002  ...                           359.0
# 1                 G2450018013  ...                           418.0
# 2                 G2470252008  ...                           367.0
# 3                 G2440105001  ...                           370.0
# 4                 G2450350008  ...                           402.0
#
#   IHS_TEMP_AVG_T_ODS_L621_TMMCR27 SCS_TEMP_AVG_T_ODS_L621_TMMCR27  \
# 0                           292.0                           465.0
# 1                           292.0                           464.0
# 2                           292.0                           469.0
# 3                           292.0                           462.0
# 4                           292.0                           445.0
#
#   SF_TEMP_AVG_T_ODS_L621_TMMCR27  RCS_TEMP_AVG_T_ODS_L621_TMMCR27  \
# 0                          700.0                            461.0
# 1                          719.0                            464.0
# 2                          699.0                            463.0
# 3                          699.0                            463.0
# 4                          701.0                            443.0
#
#    RTF_TEMP_AVG_T_ODS_L621_TMMCR27  JPF_TEMP_AVG_T_ODS_L621_TMMCR27  TS_P1  \
# 0                            851.0                            852.0  286.0
# 1                            825.0                            835.0  311.0
# 2                            849.0                            851.0  281.0
# 3                            860.0                            861.0  280.0
# 4                            863.0                            862.0  285.0
#
#    YS_8_P1  BREAK_EL_P1
# 0    133.0         45.0
# 1    206.0         44.0
# 2    130.0         50.5
# 3    135.0         47.0
# 4    135.0         45.0
#
# [5 rows x 127 columns]

# %%
#删除有缺失值所在行
data = data.dropna()
#保存删除缺失值后的数据到源文件
data.to_excel('./data/new_Industrial_data.xlsx', index=False)

# %%
#读取./data/col(1).xlsx文件
data = pd.read_excel('./data/col(1).xlsx')

# %%
#输出表头
print(data.columns)
# Out:
# Index(['Unnamed: 0', 'TABLE_CAT', 'TABLE_SCHEM', 'TABLE_NAME', 'COLUMN_NAME',
#        'DATA_TYPE', 'REMARKS', 'TYPE_NAME', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'COLUMN_SIZE', 'BUFFER_LENGTH',
#        'DECIMAL_DIGITS', 'NUM_PREC_RADIX', 'NULLABLE', 'COLUMN_DEF',
#        'SQL_DATA_TYPE', 'SQL_DATETIME_SUB', 'CHAR_OCTET_LENGTH',
#        'ORDINAL_POSITION', 'IS_NULLABLE', 'SCOPE_CATALOG', 'SCOPE_SCHEMA',
#        'SCOPE_TABLE', 'SOURCE_DATA_TYPE', 'IS_AUTOINCREMENT',
#        'IS_GENERATEDCOLUMN'],
#       dtype='object')

# %%
#添加新列COLUMN_NAME_TABLE_NAME,内容为COLUMN_NAME字符串加上下划线加上TABLE_NAME字符串
data['COLUMN_NAME_TABLE_NAME'] = data['COLUMN_NAME'] + '_' + data['TABLE_NAME']
#输出前五行数据
print(data.head())
# Out:
#    Unnamed: 0 TABLE_CAT TABLE_SCHEM      TABLE_NAME    COLUMN_NAME  DATA_TYPE  \
# 0           0    (null)    BGROL614  T_ODS_L614_CNT       GET_TIME         12
# 1           1    (null)    BGROL614  T_ODS_L614_CNT  ENTRY_COIL_NO         12
# 2           2    (null)    BGROL614  T_ODS_L614_CNT   EXIT_COIL_NO         12
# 3           3    (null)    BGROL614  T_ODS_L614_CNT            SEQ          3
# 4           4    (null)    BGROL614  T_ODS_L614_CNT          START         12
#
#   REMARKS TYPE_NAME                             Unnamed: 8    Unnamed: 9  ...  \
# 0    采集时间   VARCHAR       BGROL614.T_ODS_L614_CNT.GET_TIME   VARCHAR(30)  ...
# 1   入口材料号   VARCHAR  BGROL614.T_ODS_L614_CNT.ENTRY_COIL_NO   VARCHAR(30)  ...
# 2   出口材料号   VARCHAR   BGROL614.T_ODS_L614_CNT.EXIT_COIL_NO   VARCHAR(30)  ...
# 3      序号   DECIMAL            BGROL614.T_ODS_L614_CNT.SEQ  DECIMAL(5,0)  ...
# 4      开始   VARCHAR          BGROL614.T_ODS_L614_CNT.START   VARCHAR(30)  ...
#
#   CHAR_OCTET_LENGTH ORDINAL_POSITION  IS_NULLABLE  SCOPE_CATALOG SCOPE_SCHEMA  \
# 0                30                1          YES         (null)       (null)
# 1                30                2           NO         (null)       (null)
# 2                30                3           NO         (null)       (null)
# 3            (null)                4           NO         (null)       (null)
# 4                30                5          YES         (null)       (null)
#
#   SCOPE_TABLE  SOURCE_DATA_TYPE IS_AUTOINCREMENT  IS_GENERATEDCOLUMN  \
# 0      (null)            (null)               NO                  NO
# 1      (null)            (null)               NO                  NO
# 2      (null)            (null)               NO                  NO
# 3      (null)            (null)               NO                  NO
# 4      (null)            (null)               NO                  NO
#
#          COLUMN_NAME_TABLE_NAME
# 0       GET_TIME_T_ODS_L614_CNT
# 1  ENTRY_COIL_NO_T_ODS_L614_CNT
# 2   EXIT_COIL_NO_T_ODS_L614_CNT
# 3            SEQ_T_ODS_L614_CNT
# 4          START_T_ODS_L614_CNT
#
# [5 rows x 30 columns]

# %%
#保存添加新列后的数据到源文件
data.to_excel('./data/col(1).xlsx', index=False)

# %%
#读取./data/new_Industrial_data.xlsx文件，忽略第一行
data1 = pd.read_excel('./data/new_Industrial_data.xlsx', skiprows=1)
data2 = pd.read_excel('./data/col(1).xlsx')

# %%
#查看data1的表头
print(data1.columns)
# Out:
# Index(['MAT_WT_T_ODS_L403_TMMHR01', 'MAT_ACT_WT_T_ODS_L403_TMMHR01',
#        'MAT_ACT_THICK_T_ODS_L403_TMMHR01', 'MAT_ACT_WIDTH_T_ODS_L403_TMMHR01',
#        'MAT_TARG_THICK_T_ODS_L403_TMMHR01',
#        'MAT_TARG_WIDTH_T_ODS_L403_TMMHR01', 'SG_STD_T_ODS_L403_TMMHR01',
#        'PSC_T_ODS_L403_TMMHR01', 'APN_T_ODS_L403_TMMHR01',
#        'ORDER_NO_T_ODS_L403_TMMHR01',
#        ...
#        'FCS_TEMP_AVG_T_ODS_L621_TMMCR27', 'IHS_TEMP_AVG_T_ODS_L621_TMMCR27',
#        'SCS_TEMP_AVG_T_ODS_L621_TMMCR27', 'SF_TEMP_AVG_T_ODS_L621_TMMCR27',
#        'RCS_TEMP_AVG_T_ODS_L621_TMMCR27', 'RTF_TEMP_AVG_T_ODS_L621_TMMCR27',
#        'JPF_TEMP_AVG_T_ODS_L621_TMMCR27', 'TS_P1', 'YS_8_P1', 'BREAK_EL_P1'],
#       dtype='object', length=127)

# %%
data1_columns_zh = []
for i in data1.columns:
    #查找data2中COLUMN_NAME_TABLE_NAME列中包含data1的列名的索引
    index = data2[data2['COLUMN_NAME_TABLE_NAME'].str.contains(i)].index
    #查找该索引下data2 REMARKS列的值
    data1_columns_zh.append(data2.loc[index, 'REMARKS'].values)

print(data1_columns_zh)
#将data1_columns_zh添加到data1的第一行
data1.loc[-1] = data1_columns_zh
data1.index = data1.index + 1
data1 = data1.sort_index()
#保存添加新行后的数据到源文件
data1.to_excel('./data/new_Industrial_data.xlsx', index=False)
# Out:
# [array(['材料重量', '包装材料重量', '入口材料重量'], dtype=object), array(['材料实际重量'], dtype=object), array(['材料实际厚度', '出口材料实际厚度'], dtype=object), array(['材料实际宽度', '出口材料实际宽度'], dtype=object), array(['材料目标厚度', '出口材料目标厚度'], dtype=object), array(['材料目标宽度', '出口材料目标宽度'], dtype=object), array(['标准', '原标准', '初始标准'], dtype=object), array(['产品规范码', '原产品规范码', '初始产品规范码'], dtype=object), array(['产品最终用途码', '原产品用途码', '初始产品最终用途码'], dtype=object), array(['合同号', '原合同号', '初始合同号'], dtype=object), array(['后全程工序代码'], dtype=object), array(['品名代码'], dtype=object), array(['冶金规范码', '原冶金规范码', '初始冶金规范码'], dtype=object), array(['运输方式代码'], dtype=object), array(['卷取温度平均值'], dtype=object), array(['表面判定代码'], dtype=object), array(['加热炉号'], dtype=object), array(['装炉时间'], dtype=object), array(['出炉时间'], dtype=object), array(['出炉温度_001'], dtype=object), array(['在炉时间'], dtype=object), array(['实绩类型'], dtype=object), array(['精轧入口平均温度'], dtype=object), array(['精轧出口平均温度'], dtype=object), array(['试批号'], dtype=object), array(['牌号（钢级）', '牌号(销售)长'], dtype=object), array(['标准'], dtype=object), array(['生产日期'], dtype=object), array(['机组代码', '下道机组代码'], dtype=object), array(['生产班次号'], dtype=object), array(['生产班组'], dtype=object), array(['表面判定代码'], dtype=object), array(['出口材料目标厚度'], dtype=object), array(['出口材料目标宽度'], dtype=object), array(['出口材料实际厚度'], dtype=object), array(['出口材料实际宽度'], dtype=object), array(['出口材料实际重量'], dtype=object), array(['入口材料1厚度'], dtype=object), array(['入口材料1宽度'], dtype=object), array(['入口材料1重量'], dtype=object), array([], dtype=object), array(['切边标记'], dtype=object), array(['实际切边宽度'], dtype=object), array(['S1机架压下率'], dtype=object), array(['S2机架压下率'], dtype=object), array(['S3机架压下率'], dtype=object), array(['S4机架压下率'], dtype=object), array(['S5机架压下率'], dtype=object), array(['S1机架入口张力'], dtype=object), array(['S1～S2机架间张力'], dtype=object), array(['S2～S3机架间张力'], dtype=object), array(['S3～S4机架间张力'], dtype=object), array(['S4～S5机架间张力'], dtype=object), array(['S5出口张力'], dtype=object), array(['S1机架入口单位张力'], dtype=object), array(['S1~S2机架间单位张力'], dtype=object), array(['S2~S3机架间单位张力'], dtype=object), array(['S3~S4机架间单位张力'], dtype=object), array(['S4~S5机架间单位张力'], dtype=object), array(['S5机架工作轧辊粗糙度(底)'], dtype=object), array(['S5机架工作轧辊粗糙度(上)'], dtype=object), array(['1#机架轧制力模型设定值'], dtype=object), array(['2#机架轧制力模型设定值'], dtype=object), array(['3#机架轧制力模型设定值'], dtype=object), array(['4#机架轧制力模型设定值'], dtype=object), array(['5#机架轧制力模型设定值'], dtype=object), array(['是否拉矫标志'], dtype=object), array(['拉矫率平均值'], dtype=object), array(['1#酸槽温度'], dtype=object), array(['1#酸槽酸度'], dtype=object), array(['1#酸槽Fe3+度'], dtype=object), array(['2#酸槽温度'], dtype=object), array(['2#酸槽酸度'], dtype=object), array(['2#酸槽Fe3+度'], dtype=object), array(['3#酸槽温度'], dtype=object), array(['3#酸槽酸度'], dtype=object), array(['3#酸槽Fe3+度'], dtype=object), array(['酸洗工序速度平均值1'], dtype=object), array(['酸洗工序速度最小值1'], dtype=object), array(['酸洗工序速度最大值1'], dtype=object), array(['头部厚度5％超差长度'], dtype=object), array(['头部厚度5％超差平均值'], dtype=object), array(['头部厚度5％超差最小值'], dtype=object), array(['头部厚度5％超差最大值'], dtype=object), array(['尾部厚度5％超差长度'], dtype=object), array(['尾部厚度5％超差平均值'], dtype=object), array(['尾部厚度5％超差最小值'], dtype=object), array(['尾部厚度5％超差最大值'], dtype=object), array(['熔炼号'], dtype=object), array(['最终用户代码'], dtype=object), array(['最终用户中文名称'], dtype=object), array(['后处理代码'], dtype=object), array(['订货厚度'], dtype=object), array(['订货宽度'], dtype=object), array(['表面精度代码'], dtype=object), array(['全程工序途径码'], dtype=object), array(['碳实际值'], dtype=object), array(['硅实际值'], dtype=object), array(['锰实际值'], dtype=object), array(['磷实际值'], dtype=object), array(['硫实际值', '砷实际值'], dtype=object), array(['酸溶铝实际值'], dtype=object), array(['钛实际值'], dtype=object), array(['铌实际值'], dtype=object), array(['钼实际值', '氧实际值'], dtype=object), array(['锰实际值', '锡实际值', '锌实际值', '氮实际值'], dtype=object), array(['切边标记'], dtype=object), array(['上表面镀层重量'], dtype=object), array(['下表面镀层重量'], dtype=object), array(['平整率平均值'], dtype=object), array(['涂油种类代码'], dtype=object), ar ...

# %%
data1 = pd.read_excel('./data/new_Industrial_data.xlsx', skiprows=1)
